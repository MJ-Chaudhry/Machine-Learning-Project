# %%
import pandas as pd

df = pd.read_excel("finaccess2024_datasprint.xlsx")

df.head()

# %%
df.groupby(['Sex', 'financial_status']).size()
# Out:
# Sex     financial_status
# Female  Improved            2299
#         Stayed the same     3260
#         Worsened            6767
# Male    Improved            1982
#         Stayed the same     2349
#         Worsened            4214
# dtype: int64
